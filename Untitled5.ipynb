# %%
import pandas as pd

# %%
# Load the dataset
file_path = '/content/user_behavior_dataset.csv'
data = pd.read_csv(file_path)

# %%
# Preview the dataset
print("Dataset Head:\n", data.head())
print("\nColumns:\n", data.columns)
print("\nSummary Statistics:\n", data.describe())
# Out:
# Dataset Head:
#     User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...

# %%
# Check for missing values
print("\nMissing Values:\n", data.isnull().sum())
# Out:
# Missing Values:
#  User ID                       0
# Device Model                  0
# Operating System              0
# App Usage Time (min/day)      0
# Screen On Time (hours/day)    0
# Battery Drain (mAh/day)       0
# Number of Apps Installed      0
# Data Usage (MB/day)           0
# Age                           0
# Gender                        0
# User Behavior Class           0
# dtype: int64

# %%
# Example Analysis
# Check the shape of the dataset
print(f"\nNumber of Rows: {data.shape[0]}, Columns: {data.shape[1]}")
# Out:
# Number of Rows: 700, Columns: 11

# %%
# Example Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Histogram for App Usage Time
plt.figure(figsize=(8, 6))
sns.histplot(data['App Usage Time (min/day)'], bins=20, kde=True, color='blue')
plt.title('Distribution of App Usage Time')
plt.xlabel('App Usage Time (min/day)')
plt.ylabel('Frequency')
plt.show()

# Boxplot for App Usage by Gender
plt.figure(figsize=(8, 6))
sns.boxplot(x='Gender', y='App Usage Time (min/day)', data=data, palette='pastel')
plt.title('App Usage Time by Gender')
plt.show()
# Out:
# <ipython-input-14-d66cbfb87661>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Gender', y='App Usage Time (min/day)', data=data, palette='pastel')

# %%
# Distribution of User Behavior Class
plt.figure(figsize=(8, 6))
sns.countplot(x='User Behavior Class', data=data, palette='coolwarm')
plt.title("Distribution of User Behavior Class")
plt.xlabel("User Behavior Class")
plt.ylabel("Count")
plt.show()
# Out:
# <ipython-input-17-f45ea80a9ca1>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='User Behavior Class', data=data, palette='coolwarm')

# %% [markdown]
# Below is a detailed Python script to prepare the dataset for classification analysis and predict User Behavior Class.
#
# 1. Data Preparation

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Encode categorical variables
data_encoded = data.copy()
categorical_columns = ['Gender', 'Operating System']

for col in categorical_columns:
    le = LabelEncoder()
    data_encoded[col] = le.fit_transform(data_encoded[col])

# Select features and target variable
features = data_encoded[['App Usage Time (min/day)', 'Screen On Time (hours/day)',
                         'Battery Drain (mAh/day)', 'Number of Apps Installed',
                         'Data Usage (MB/day)', 'Age', 'Gender', 'Operating System']]
target = data_encoded['User Behavior Class']

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %% [markdown]
# 2. Train a Classifier
# Using a Random Forest Classifier as an example:

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize and train the model
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# %% [markdown]
# 3. Evaluate the Model

# %%
from sklearn.metrics import classification_report, accuracy_score

# Calculate accuracy and classification metrics
accuracy = accuracy_score(y_test, y_pred)
classification_report_output = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Classification Report:\n", classification_report_output)
# Out:
# Accuracy: 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        27
#            2       1.00      1.00      1.00        29
#            3       1.00      1.00      1.00        34
#            4       1.00      1.00      1.00        27
#            5       1.00      1.00      1.00        23
#
#     accuracy                           1.00       140
#    macro avg       1.00      1.00      1.00       140
# weighted avg       1.00      1.00      1.00       140
